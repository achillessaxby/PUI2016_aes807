# %%
import pandas as pd
import os

# %%
os.getenv('DFDATA')
# Out:
# '/gws/open/NYCOpenData/nycopendata/data'

# %%
dataFile = os.getenv('DFDATA') + '/' + 'ic3t-wcy2/1473437392/ic3t-wcy2.csv'

# %%
data = pd.read_csv(dataFile)
data.head()
# Out:
#        Job #  Doc #        Borough       House #  \
# 0  121577873      2      MANHATTAN  386
# 1  520129502      1  STATEN ISLAND  107
# 2  121601560      1      MANHATTAN  63
# 3  121601203      1      MANHATTAN  48
# 4  121601338      1      MANHATTAN  45
#
#                         Street Name  Block   Lot      Bin # Job Type  \
# 0  PARK AVENUE SOUTH                   857  38.0  1016890.0       A2
# 1  KNOX PLACE                          342   1.0  5161350.0       A3
# 2  WEST 131 STREET                    1729   9.0  1053831.0       A2
# 3  WEST 25TH STREET                    826  69.0  1015610.0       A2
# 4  WEST 29 STREET                      831   7.0  1015754.0       A3
#
#   Job Status           ...                         Owner's Last Name  \
# 0          D           ...            MIGLIORE
# 1          A           ...            BLUMENBERG
# 2          Q           ...            MARKOWITZ
# 3          D           ...            CASALE
# ...

# %%
data.columns
# Out:
# Index([u'Job #', u'Doc #', u'Borough', u'House #', u'Street Name', u'Block',
#        u'Lot', u'Bin #', u'Job Type', u'Job Status', u'Job Status Descrp',
#        u'Latest Action Date', u'Building Type', u'Community - Board',
#        u'Cluster', u'Landmarked', u'Adult Estab', u'Loft Board', u'City Owned',
#        u'Little e', u'PC Filed', u'eFiling Filed', u'Plumbing', u'Mechanical',
#        u'Boiler', u'Fuel Burning', u'Fuel Storage', u'Standpipe', u'Sprinkler',
#        u'Fire Alarm', u'Equipment', u'Fire Suppression', u'Curb Cut', u'Other',
#        u'Other Description', u'Applicant's First Name',
#        u'Applicant's Last Name', u'Applicant Professional Title',
#        u'Applicant License #', u'Professional Cert', u'Pre- Filing Date',
#        u'Paid', u'Fully Paid', u'Assigned', u'Approved', u'Fully Permitted',
#        u'Initial Cost', u'Total Est. Fee', u'Fee Status',
#        u'Existing Zoning Sqft', u'Proposed Zoning Sqft', u'Horizontal Enlrgmt',
# ...

# %%
data[["Block","Job #"]].head()
# Out:
#    Block      Job #
# 0    857  121577873
# 1    342  520129502
# 2   1729  121601560
# 3    826  121601203
# 4    831  121601338

# %%
data[["Block","Job #"]]
# Out:
#         Block      Job #
# 0         857  121577873
# 1         342  520129502
# 2        1729  121601560
# 3         826  121601203
# 4         831  121601338
# 5         835  121589753
# 6        1846  320738001
# 7          76  121601374
# 8        1447  121583054
# 9        9999  121601392
# 10       1306  121601169
# 11        832  420828206
# 12       9677  420828493
# 13       4518  440075142
# 14       1455  420836723
# 15        439  121584525
# 16        696  121600311
# 17       1586  320744290
# 18       2287  320744557
# 19       2922  320744370
# 20       3186  220286232
# 21       1339  121599779
# 22      13972  420837401
# 23       5141  220286287
# 24       5263  240024362
# 25       2421  320744316
# 26       1312  121601249
# 27       1267  121592605
# 28        857  121577873
# 29       3649  520129496
# ...       ...        ...
# 246232   1436  140547139
# 246233    787  122884735
# 246234   3782  321448750
# 246235   6247  321448830
# 246236   2518  240155988
# ...

# %%
data[["Block","Lot"]]
# Out:
#         Block     Lot
# 0         857    38.0
# 1         342     1.0
# 2        1729     9.0
# 3         826    69.0
# 4         831     7.0
# 5         835    41.0
# 6        1846     9.0
# 7          76  7502.0
# 8        1447    27.0
# 9        9999     1.0
# 10       1306    50.0
# 11        832    57.0
# 12       9677     1.0
# 13       4518    53.0
# 14       1455     7.0
# 15        439    27.0
# 16        696    13.0
# 17       1586    34.0
# 18       2287     1.0
# 19       2922    39.0
# 20       3186    76.0
# 21       1339    19.0
# 22      13972    64.0
# 23       5141     3.0
# 24       5263    40.0
# 25       2421     7.0
# 26       1312    41.0
# 27       1267     1.0
# 28        857    38.0
# 29       3649    27.0
# ...       ...     ...
# 246232   1436    44.0
# 246233    787    72.0
# 246234   3782   130.0
# 246235   6247    78.0
# 246236   2518    31.0
# 246237   6811    18.0
# 246238    763    23.0
# 246239   3740    34.0
# 246240   1234     5.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# DataFrame.plot.scatter(data)

df = pd.DataFrame(data[["Block","Lot"]], columns=['Block','Lot'])
df.plot.scatter(x='Block', y='Lot');

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.DataFrame(data[["Block","Job #"]], columns=['Block','Job #'])
df.plot.scatter(x='Block', y='Job #',title='Pandas Plotting with Data from NYCOpenData');

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

ts = pd.DataFrame(data[["Block","Job #"]], columns=['Block','Job #'])
#df.plot.scatter(x='Block', y='Job #',title='Pandas Plotting with Data from NYCOpenData');

ts.plot()

df = ts.plot.scatter(x='Block', y='Job #',title='Pandas Plotting with Data from NYCOpenData')

plt.figure(); 
df.plot();

# %%
import matplotlib.pyplot as plt
import matplotlib
#matplotlib.style.use('ggplot')
# %matplotlib inline


df = pd.DataFrame(data[["Block","Job #"]], columns=['Block','Job #'])
df.plot.scatter(x='Block', y='Job #',title='Pandas Plotting with Data from NYCOpenData');

plt.title('NYCOpenData Plotting', fontsize = 15 , color='red')

plt.text(0,1, 'Figure 1:', fontsize = 9, fontweight = 'bold')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

df = pd.DataFrame(data[["Block","Job #"]], columns=['Block','Job #'])

df.plot.scatter(x='Block', y='Job #', color='DarkBlue', label='Block v/s Job #');

plt.title('NYCOpenData Plotting', fontsize = 15 , color='red')

plt.text(0,-150000000,'Figure : Assignment 3 Plotting', fontsize = 10, fontweight = 'bold')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

df = pd.DataFrame(data[["Block","Lot"]], columns=['Block','Lot'])

df.plot.scatter(x='Block', y='Lot', color='DarkBlue', label='Block v/s Lot');

plt.title('NYCOpenData Plotting', fontsize = 15 , color='red')

plt.text(-20000,-5000,'Figure : Assignment 3 Plotting', fontsize = 10, fontweight = 'bold')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

df = pd.DataFrame(data[["Job #","Bin #"]], columns=['Job #','Bin #'])

df.plot.scatter(x='Job #', y='Bin #', color='DarkBlue', label='Job v/s Bin #');

plt.title('NYCOpenData Plotting', fontsize = 15 , color='red')

plt.text(0,-1500000,'Figure : Assignment 3 Plotting', fontsize = 10, fontweight = 'bold')

plt.legend(loc='upper left')
plt.show()
